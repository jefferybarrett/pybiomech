# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from pybiomech.featherstone import test_func
#
# ModuleNotFoundError: No module named 'pybiomech'

# %% [markdown]
# # This is a test
#
# We are computing $f(x)=x^2$ in this notebook. That's very important!

# %%
x = np.linspace(0, 1, 256)
y = x**2
plt.plot(x,y, 'k')
plt.show()
